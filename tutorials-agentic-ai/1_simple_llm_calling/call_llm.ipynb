# %%
from dotenv import load_dotenv
import os
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %%
True
# Out:
# True

# %%
api_key = os.getenv("GOOGLE_API_KEY")

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=api_key,
    temperature=0
)

response = llm.invoke("How many moons does Jupiter have?")

print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# As of my last update, Jupiter has **95 confirmed moons**.
#
# This number can change as new moons are discovered and confirmed. The most famous are the four large Galilean moons:
# *   **Io**
# *   **Europa**
# *   **Ganymede** (the largest moon in the solar system)
# *   **Callisto**
#
# The vast majority of the other moons are much smaller and irregularly shaped.

# %%
response = llm.invoke([
    ["system", "You are a helpful assistant that answers in short one line"],
    ["human", "How many moons does Jupiter have?"]
])
print(response.text)
